# %% [markdown]
# # Capstone project week 1

# %% [markdown]
# ### Import necessary Libraries

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'OCPIGWZCECJWNPVJC1UG33OCEGWAQDVEQINQAWKAYVR0DQMY' # your Foursquare ID
CLIENT_SECRET = 'SVMEUZK1U3INHIUNBVJZKNIU3UM1DHVLQQ25LKEFRRVTXHV0' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 20
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OCPIGWZCECJWNPVJC1UG33OCEGWAQDVEQINQAWKAYVR0DQMY
# CLIENT_SECRET:SVMEUZK1U3INHIUNBVJZKNIU3UM1DHVLQQ25LKEFRRVTXHV0

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %%
address = 'north york,Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 43.7708175 -79.4132998

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'school'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# school .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=OCPIGWZCECJWNPVJC1UG33OCEGWAQDVEQINQAWKAYVR0DQMY&client_secret=SVMEUZK1U3INHIUNBVJZKNIU3UM1DHVLQQ25LKEFRRVTXHV0&ll=43.7708175,-79.4132998&v=20180604&query=school&radius=1000&limit=20'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c8aeba1f594df7cdf93a4d5'},
#  'response': {'venues': [{'id': '5134b8b7e4b08268919a93da',
#     'name': 'Canadian Academic Succes School',
#     'location': {'address': '5310A Yonge Street',
#      'lat': 43.772921,
#      'lng': -79.414293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.772921,
#        'lng': -79.414293}],
#      'distance': 247,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5310A Yonge Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '5936d04f123a196a4d4b6446',
#     'name': 'Stafford House English school',
#     'location': {'lat': 43.768578757337266,
#      'lng': -79.41489055983754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.768578757337266,
#        'lng': -79.41489055983754}],
#      'distance': 280,
#      'postalCode': 'M2N 6L4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M2N 6L4', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '55f030a9498e6f3af1c04983',
#     'name': 'Lansing Co-operative Nursery School & Kindergarten',
#     'location': {'address': '80 Church Ave',
#      'crossStreet': 'At Kenneth',
#      'lat': 43.77487829929666,
#      'lng': -79.4095927476883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77487829929666,
#        'lng': -79.4095927476883}],
#      'distance': 541,
#      'postalCode': 'M2N 4G1',
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['80 Church Ave (At Kenneth)', 'M2N 4G1', 'Canada']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0107',
#       'name': 'Nursery School',
#       'pluralName': 'Nursery Schools',
#       'shortName': 'Nursery School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4e1b18eb45dd5191e7c1ff5c',
#     'name': 'McKee Public School',
#     'location': {'address': '35 Church Ave',
#      'crossStreet': 'btwn Doris Ave & Kenneth Ave',
#      'lat': 43.77410726583206,
#      'lng': -79.41158555630057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77410726583206,
#        'lng': -79.41158555630057}],
#      'distance': 391,
#      'postalCode': 'M2N 6X6',
#      'cc': 'CA',
#      'neighborhood': 'Willowdale, Toronto, ON',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['35 Church Ave (btwn Doris Ave & Kenneth Ave)',
#       'Toronto ON M2N 6X6',
#       'Canada']},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4bb0ae69f964a52085543ce3',
#     'name': 'Earl Haig Secondary School',
#     'location': {'address': '100 Princess Ave',
#      'crossStreet': 'Empress & Dudley',
#      'lat': 43.769686340527876,
#      'lng': -79.40680255359896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.769686340527876,
#        'lng': -79.40680255359896}],
#      'distance': 537,
#      'postalCode': 'M2N 3R7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Princess Ave (Empress & Dudley)',
#       'Toronto ON M2N 3R7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '5509e578498e03eff4d6ac0a',
#     'name': 'Omnicom School of Languages',
#     'location': {'address': '5 Park Home Avenue',
#      'crossStreet': 'Yonge and Park Home',
#      'lat': 43.768637843878665,
#      'lng': -79.4148337841034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.768637843878665,
#        'lng': -79.4148337841034}],
#      'distance': 272,
#      'postalCode': 'M2N 6L4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5 Park Home Avenue (Yonge and Park Home)',
#       'Toronto ON M2N 6L4',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '124988535'},
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4c92a1b8d84a6dcba8643687',
#     'name': 'Yamaha Music School',
#     'location': {'address': '5075 Yonge street',
#      'lat': 43.76769273973068,
#      'lng': -79.41235456399878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76769273973068,
#        'lng': -79.41235456399878}],
#      'distance': 356,
#      'postalCode': 'M2N 6C6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5075 Yonge street',
#       'Toronto ON M2N 6C6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4dc034fc6a23e5a549e667e5',
#     'name': 'Omnicom English School',
#     'location': {'lat': 43.76862887430527,
#      'lng': -79.41479599483121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76862887430527,
#        'lng': -79.41479599483121}],
#      'distance': 271,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4d4b7105d754a06372d81259',
#       'name': 'College & University',
#       'pluralName': 'Colleges & Universities',
#       'shortName': 'College & Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4d594e703281b1f75ea8b92f',
#     'name': 'Toronto catholic District School Board',
#     'location': {'address': '80 Sheppard Ave E',
#      'lat': 43.76345905686273,
#      'lng': -79.40788523370291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76345905686273,
#        'lng': -79.40788523370291}],
#      'distance': 927,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['80 Sheppard Ave E', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4be0768f652b0f4764877211',
#     'name': 'Claude Watson School',
#     'location': {'lat': 43.76603522172218,
#      'lng': -79.41080781501282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76603522172218,
#        'lng': -79.41080781501282}],
#      'distance': 568,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d199941735',
#       'name': 'College Arts Building',
#       'pluralName': 'College Arts Buildings',
#       'shortName': 'Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4f957ccde4b05b20f20ef20c',
#     'name': 'Omnicom English School II',
#     'location': {'lat': 43.76514013192576,
#      'lng': -79.41231582389955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76514013192576,
#        'lng': -79.41231582389955}],
#      'distance': 636,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4bab5d8af964a520b8a33ae3',
#     'name': 'Toronto District School Board',
#     'location': {'address': '5050 Yonge St',
#      'lat': 43.76602951334348,
#      'lng': -79.4108636304489,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76602951334348,
#        'lng': -79.4108636304489}],
#      'distance': 567,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5050 Yonge St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '598c9974dd84420428480d92',
#     'name': 'Yorktown Montessori School',
#     'location': {'crossStreet': 'Kenneth Ave',
#      'lat': 43.7756249712888,
#      'lng': -79.41035020326608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7756249712888,
#        'lng': -79.41035020326608}],
#      'distance': 585,
#      'postalCode': 'M2N 4V9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Kenneth Ave', 'Toronto ON M2N 4V9', 'Canada']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0107',
#       'name': 'Nursery School',
#       'pluralName': 'Nursery Schools',
#       'shortName': 'Nursery School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4e6618a61838ad3d105cdd42',
#     'name': 'St. Cyril Catholic School',
#     'location': {'lat': 43.77707113713509,
#      'lng': -79.41553678455666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77707113713509,
#        'lng': -79.41553678455666}],
#      'distance': 718,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4e8734d3f79018e1597cf628',
#     'name': 'Willowdale Middle School',
#     'location': {'address': '225 Senlac',
#      'lat': 43.769767072637364,
#      'lng': -79.42644654082916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.769767072637364,
#        'lng': -79.42644654082916}],
#      'distance': 1063,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['225 Senlac', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4f4533814b9074f6e4fb0106',
#       'name': 'Middle School',
#       'pluralName': 'Middle Schools',
#       'shortName': 'Middle School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4c21983d13c00f47874486de',
#     'name': 'Willowdale High School',
#     'location': {'crossStreet': 'Scarsdale and Ellesmere',
#      'lat': 43.769915,
#      'lng': -79.426427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.769915,
#        'lng': -79.426427}],
#      'distance': 1060,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'shortName': 'High School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '5c1c79b3dd70c500393f1d38',
#     'name': 'Ontario Virtual School (Online High School)',
#     'location': {'address': '4773 Yonge St',
#      'lat': 43.761232,
#      'lng': -79.410459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.761232,
#        'lng': -79.410459}],
#      'distance': 1091,
#      'postalCode': 'M2N 0G2',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4773 Yonge St', 'North York ON M2N 0G2', 'Canada']},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4bf6e46e13aed13a8968eaf7',
#     'name': 'Churchill Public School',
#     'location': {'crossStreet': 'Churchill senelac',
#      'lat': 43.771166658372834,
#      'lng': -79.42674880788688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.771166658372834,
#        'lng': -79.42674880788688}],
#      'distance': 1081,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '5bec8c1fb9a5a8002c4ed72c',
#     'name': 'EAS International School',
#     'location': {'address': 'Unit906, 4789 Yonge St',
#      'crossStreet': 'Sheppard Ave',
#      'lat': 43.761102,
#      'lng': -79.409971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.761102,
#        'lng': -79.409971}],
#      'distance': 1114,
#      'postalCode': 'M2N 0G3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Unit906, 4789 Yonge St (Sheppard Ave)',
#       'Toronto ON M2N 0G3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False},
#    {'id': '4e7df5016c25f10ae8e2fc7a',
#     'name': 'Bayview School of Ballet',
#     'location': {'address': '148 Willowdale Ave.',
#      'crossStreet': 'Sheppard And Willowdale',
#      'lat': 43.766098066223016,
#      'lng': -79.4007117387402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.766098066223016,
#        'lng': -79.4007117387402}],
#      'distance': 1140,
#      'postalCode': 'M2N 4Y4',
#      'cc': 'CA',
#      'city': 'North York',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['148 Willowdale Ave. (Sheppard And Willowdale)',
#       'North York ON M2N 4Y4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1552608161',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                                                              categories  \
# 0  [{'id': '4bf58dd8d48988d198941735', 'name': 'College Academic Building', 'pluralName': 'College Academic Buildings', 'shortName': 'Academic Building', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '52e81612bcbc57f1066b7a48', 'name': 'Language School', 'pluralName': 'Language Schools', 'shortName': 'Language School', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4f4533814b9074f6e4fb0107', 'name': 'Nursery School', 'pluralName': 'Nursery Schools', 'shortName': 'Nursery School', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4f4533804b9074f6e4fb0105', 'name': 'Elementary School', 'pluralName': 'Elementary Schools', 'shortName': 'Elementary School', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d13d941735', 'name': 'High School', 'pluralName': 'High Schools', 'shortName': 'High School', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}, 'primary': True}]
#
#    hasPerk                        id    location.address location.cc  \
# 0  False    5134b8b7e4b08268919a93da  5310A Yonge Street  CA
# 1  False    5936d04f123a196a4d4b6446  NaN                 CA
# 2  False    55f030a9498e6f3af1c04983  80 Church Ave       CA
# 3  False    4e1b18eb45dd5191e7c1ff5c  35 Church Ave       CA
# 4  False    4bb0ae69f964a52085543ce3  100 Princess Ave    CA
#
#   location.city location.country          location.crossStreet  \
# 0  Toronto       Canada           NaN
# 1  Toronto       Canada           NaN
# 2  NaN           Canada           At Kenneth
# 3  Toronto       Canada           btwn Doris Ave & Kenneth Ave
# 4  Toronto       Canada           Empress & Dudley
#
#    location.distance  \
# 0  247
# 1  280
# 2  541
# 3  391
# 4  537
#
#                                                     location.formattedAddress  \
# 0  [5310A Yonge Street, Toronto ON, Canada]
# 1  [Toronto ON M2N 6L4, Canada]
# 2  [80 Church Ave (At Kenneth), M2N 4G1, Canada]
# 3  [35 Church Ave (btwn Doris Ave & Kenneth Ave), Toronto ON M2N 6X6, Canada]
# 4  [100 Princess Ave (Empress & Dudley), Toronto ON M2N 3R7, Canada]
#
#                                                         location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 43.772921, 'lng': -79.414293}]
# 1  [{'label': 'display', 'lat': 43.768578757337266, 'lng': -79.41489055983754}]
# 2  [{'label': 'display', 'lat': 43.77487829929666, 'lng': -79.4095927476883}]
# 3  [{'label': 'display', 'lat': 43.77410726583206, 'lng': -79.41158555630057}]
# 4  [{'label': 'display', 'lat': 43.769686340527876, 'lng': -79.40680255359896}]
#
#    location.lat  location.lng    location.neighborhood location.postalCode  \
# 0  43.772921    -79.414293     NaN                      NaN
# 1  43.768579    -79.414891     NaN                      M2N 6L4
# 2  43.774878    -79.409593     NaN                      M2N 4G1
# 3  43.774107    -79.411586     Willowdale, Toronto, ON  M2N 6X6
# 4  43.769686    -79.406803     NaN                      M2N 3R7
#
#   location.state                                                name  \
# 0  ON             Canadian Academic Succes School
# 1  ON             Stafford House English school
# 2  NaN            Lansing Co-operative Nursery School & Kindergarten
# 3  ON             McKee Public School
# 4  ON             Earl Haig Secondary School
#
#      referralId venuePage.id
# 0  v-1552608161  NaN
# 1  v-1552608161  NaN
# 2  v-1552608161  NaN
# 3  v-1552608161  NaN
# 4  v-1552608161  NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                   name  \
# 0   Canadian Academic Succes School
# 1   Stafford House English school
# 2   Lansing Co-operative Nursery School & Kindergarten
# 3   McKee Public School
# 4   Earl Haig Secondary School
# 5   Omnicom School of Languages
# 6   Yamaha Music School
# 7   Omnicom English School
# 8   Toronto catholic District School Board
# 9   Claude Watson School
# 10  Omnicom English School II
# 11  Toronto District School Board
# 12  Yorktown Montessori School
# 13  St. Cyril Catholic School
# 14  Willowdale Middle School
# 15  Willowdale High School
# 16  Ontario Virtual School (Online High School)
# 17  Churchill Public School
# 18  EAS International School
# 19  Bayview School of Ballet
#
#                          categories                 address  cc        city  \
# 0   College Academic Building        5310A Yonge Street      CA  Toronto
# 1   Language School                  NaN                     CA  Toronto
# 2   Nursery School                   80 Church Ave           CA  NaN
# 3   Elementary School                35 Church Ave           CA  Toronto
# 4   High School                      100 Princess Ave        CA  Toronto
# 5   Language School                  5 Park Home Avenue      CA  Toronto
# 6   College Classroom                5075 Yonge street       CA  Toronto
# 7   College & University             NaN                     CA  Toronto
# 8   College Administrative Building  80 Sheppard Ave E       CA  NaN
# 9   College Arts Building            NaN                     CA  NaN
# 10  Student Center                   NaN                     CA  Toronto
# 11  College Administrative Building  5050 Yonge St           CA  Toronto
# 12  Nursery School                   NaN                     CA  Toronto
# 13  School                           NaN                     CA  NaN
# 14  Middle School                    225 Senlac              CA  Toronto
# 15  High School                      NaN                     CA  Toronto
# 16  Elementary School                4773 Yonge St           CA  North York
# 17  School                           NaN                     CA  Toronto
# 18  School                           Unit906, 4789 Yonge St  CA  Toronto
# 19  Gym                              148 Willowdale Ave.     CA  North York
#
#    country                   crossStreet  distance  \
# 0   Canada  NaN                           247
# 1   Canada  NaN                           280
# 2   Canada  At Kenneth                    541
# 3   Canada  btwn Doris Ave & Kenneth Ave  391
# 4   Canada  Empress & Dudley              537
# 5   Canada  Yonge and Park Home           272
# 6   Canada  NaN                           356
# 7   Canada  NaN                           271
# 8   Canada  NaN                           927
# 9   Canada  NaN                           568
# 10  Canada  NaN                           636
# 11  Canada  NaN                           567
# 12  Canada  Kenneth Ave                   585
# 13  Canada  NaN                           718
# 14  Canada  NaN                           1063
# 15  Canada  Scarsdale and Ellesmere       1060
# 16  Canada  NaN                           1091
# 17  Canada  Churchill senelac             1081
# 18  Canada  Sheppard Ave                  1114
# 19  Canada  Sheppard And Willowdale       1140
#
#                                                                   formattedAddress  \
# 0   [5310A Yonge Street, Toronto ON, Canada]
# 1   [Toronto ON M2N 6L4, Canada]
# 2   [80 Church Ave (At Kenneth), M2N 4G1, Canada]
# 3   [35 Church Ave (btwn Doris Ave & Kenneth Ave), Toronto ON M2N 6X6, Canada]
# 4   [100 Princess Ave (Empress & Dudley), Toronto ON M2N 3R7, Canada]
# 5   [5 Park Home Avenue (Yonge and Park Home), Toronto ON M2N 6L4, Canada]
# 6   [5075 Yonge street, Toronto ON M2N 6C6, Canada]
# 7   [Toronto ON, Canada]
# 8   [80 Sheppard Ave E, Canada]
# 9   [Canada]
# 10  [Toronto ON, Canada]
# 11  [5050 Yonge St, Toronto ON, Canada]
# 12  [Kenneth Ave, Toronto ON M2N 4V9, Canada]
# 13  [Canada]
# 14  [225 Senlac, Toronto ON, Canada]
# 15  [Toronto ON, Canada]
# 16  [4773 Yonge St, North York ON M2N 0G2, Canada]
# 17  [Toronto ON, Canada]
# 18  [Unit906, 4789 Yonge St (Sheppard Ave), Toronto ON M2N 0G3, Canada]
# 19  [148 Willowdale Ave. (Sheppard And Willowdale), North York ON M2N 4Y4, Canada]
#
#                                                                   labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 43.772921, 'lng': -79.414293}]
# 1   [{'label': 'display', 'lat': 43.768578757337266, 'lng': -79.41489055983754}]
# 2   [{'label': 'display', 'lat': 43.77487829929666, 'lng': -79.4095927476883}]
# 3   [{'label': 'display', 'lat': 43.77410726583206, 'lng': -79.41158555630057}]
# 4   [{'label': 'display', 'lat': 43.769686340527876, 'lng': -79.40680255359896}]
# 5   [{'label': 'display', 'lat': 43.768637843878665, 'lng': -79.4148337841034}]
# 6   [{'label': 'display', 'lat': 43.76769273973068, 'lng': -79.41235456399878}]
# 7   [{'label': 'display', 'lat': 43.76862887430527, 'lng': -79.41479599483121}]
# 8   [{'label': 'display', 'lat': 43.76345905686273, 'lng': -79.40788523370291}]
# 9   [{'label': 'display', 'lat': 43.76603522172218, 'lng': -79.41080781501282}]
# 10  [{'label': 'display', 'lat': 43.76514013192576, 'lng': -79.41231582389955}]
# 11  [{'label': 'display', 'lat': 43.76602951334348, 'lng': -79.4108636304489}]
# 12  [{'label': 'display', 'lat': 43.7756249712888, 'lng': -79.41035020326608}]
# 13  [{'label': 'display', 'lat': 43.77707113713509, 'lng': -79.41553678455666}]
# 14  [{'label': 'display', 'lat': 43.769767072637364, 'lng': -79.42644654082916}]
# 15  [{'label': 'display', 'lat': 43.769915, 'lng': -79.426427}]
# 16  [{'label': 'display', 'lat': 43.761232, 'lng': -79.410459}]
# 17  [{'label': 'display', 'lat': 43.771166658372834, 'lng': -79.42674880788688}]
# 18  [{'label': 'display', 'lat': 43.761102, 'lng': -79.409971}]
# 19  [{'label': 'display', 'lat': 43.766098066223016, 'lng': -79.4007117387402}]
#
#           lat        lng             neighborhood postalCode state  \
# 0   43.772921 -79.414293  NaN                      NaN        ON
# 1   43.768579 -79.414891  NaN                      M2N 6L4    ON
# 2   43.774878 -79.409593  NaN                      M2N 4G1    NaN
# 3   43.774107 -79.411586  Willowdale, Toronto, ON  M2N 6X6    ON
# 4   43.769686 -79.406803  NaN                      M2N 3R7    ON
# 5   43.768638 -79.414834  NaN                      M2N 6L4    ON
# 6   43.767693 -79.412355  NaN                      M2N 6C6    ON
# 7   43.768629 -79.414796  NaN                      NaN        ON
# 8   43.763459 -79.407885  NaN                      NaN        NaN
# 9   43.766035 -79.410808  NaN                      NaN        NaN
# 10  43.765140 -79.412316  NaN                      NaN        ON
# 11  43.766030 -79.410864  NaN                      NaN        ON
# 12  43.775625 -79.410350  NaN                      M2N 4V9    ON
# 13  43.777071 -79.415537  NaN                      NaN        NaN
# 14  43.769767 -79.426447  NaN                      NaN        ON
# 15  43.769915 -79.426427  NaN                      NaN        ON
# 16  43.761232 -79.410459  NaN                      M2N 0G2    ON
# 17  43.771167 -79.426749  NaN                      NaN        ON
# 18  43.761102 -79.409971  NaN                      M2N 0G3    ON
# 19  43.766098 -79.400712  NaN                      M2N 4Y4    ON
#
#                           id
# 0   5134b8b7e4b08268919a93da
# 1   5936d04f123a196a4d4b6446
# 2   55f030a9498e6f3af1c04983
# 3   4e1b18eb45dd5191e7c1ff5c
# 4   4bb0ae69f964a52085543ce3
# 5   5509e578498e03eff4d6ac0a
# 6   4c92a1b8d84a6dcba8643687
# 7   4dc034fc6a23e5a549e667e5
# 8   4d594e703281b1f75ea8b92f
# 9   4be0768f652b0f4764877211
# 10  4f957ccde4b05b20f20ef20c
# 11  4bab5d8af964a520b8a33ae3
# 12  598c9974dd84420428480d92
# 13  4e6618a61838ad3d105cdd42
# 14  4e8734d3f79018e1597cf628
# 15  4c21983d13c00f47874486de
# 16  5c1c79b3dd70c500393f1d38
# 17  4bf6e46e13aed13a8968eaf7
# 18  5bec8c1fb9a5a8002c4ed72c
# 19  4e7df5016c25f10ae8e2fc7a

# %% [markdown]
# #### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0     Canadian Academic Succes School
# 1     Stafford House English school
# 2     Lansing Co-operative Nursery School & Kindergarten
# 3     McKee Public School
# 4     Earl Haig Secondary School
# 5     Omnicom School of Languages
# 6     Yamaha Music School
# 7     Omnicom English School
# 8     Toronto catholic District School Board
# 9     Claude Watson School
# 10    Omnicom English School II
# 11    Toronto District School Board
# 12    Yorktown Montessori School
# 13    St. Cyril Catholic School
# 14    Willowdale Middle School
# 15    Willowdale High School
# 16    Ontario Virtual School (Online High School)
# 17    Churchill Public School
# 18    EAS International School
# 19    Bayview School of Ballet
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the center
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='center',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore a Given Venue
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Let's explore the closest Italian restaurant -- _Harry's Italian Pizza Bar_

# %%
venue_id = '4b8bffc6f964a52076b732e3' # ID 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b8bffc6f964a52076b732e3?client_id=OCPIGWZCECJWNPVJC1UG33OCEGWAQDVEQINQAWKAYVR0DQMY&client_secret=SVMEUZK1U3INHIUNBVJZKNIU3UM1DHVLQQ25LKEFRRVTXHV0&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b8bffc6f964a52076b732e3',
#  'name': 'Ichiban Fish House',
#  'contact': {'phone': '4165127899', 'formattedPhone': '(416) 512-7899'},
#  'location': {'address': '15 Spring Garden Ave.',
#   'crossStreet': 'at Yonge St.',
#   'lat': 43.76599495334784,
#   'lng': -79.4108127227573,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.76599495334784,
#     'lng': -79.4108127227573}],
#   'postalCode': 'M2N 3G1',
#   'cc': 'CA',
#   'city': 'North York',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['15 Spring Garden Ave. (at Yonge St.)',
#    'North York ON M2N 3G1',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/ichiban-fish-house/4b8bffc6f964a52076b732e3',
#  'categories': [{'id': '4bf58dd8d48988d111941735',
#    'name': 'Japanese Restaurant',
#    'pluralName': 'Japanese Restaurants',
#    'shortName': 'Japanese',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d113941735',
#    'name': 'Korean Restaurant',
#    'pluralName': 'Korean Restaurants',
#    'shortName': 'Korean',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 18},
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 12,
#   'groups': [{'type': 'others', 'count': 12, 'items': []}],
#   'summary': '12 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 5.7,
#  'ratingColor': 'FF9600',
#  'ratingSignals': 35,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/ichiban-fish-house/4b8bffc6f964a52076b732e3/menu',
#   'mobileUrl': 'https://foursquare.com/v/4b8bffc6f964a52076b732e3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 33,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 33,
#     'items': [{'id': '50bc3284e4b0b98445db86e7',
#       'createdAt': 1354510980,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/16995036_1XBrQIjDtaIwuhIypjyS1GsFhPBEsH7YHvCyxd7MGzU.jpg',
#       'width': 540,
#       'height': 540,
#       'user': {'id': '16995036',
#        'firstName': 'Ilona',
#        'lastName': 'K',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/16995036-LBLSYY1RO2SZ3Q2X.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1267466182,
#  'tips': {'count': 18,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 18,
#     'items': [{'id': '4fab01a1e4b06c670e313bb9',
#       'createdAt': 1336607137,
#       'text': 'The chirashi salmon is served with fresh salmon sashimi and excellent sushi rice. The spider roll is also really tasty!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4fab01a1e4b06c670e313bb9',
#       'lang': 'en',
#       'likes': {'count': 1,
#        'groups': [{'type': 'others',
#          'count': 1,
#          'items': [{'id': '376806',
#            'firstName': 'Aivory',
#            'lastName': 'Gaw',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/376806-C25MZW402EYMV1E0.jpg'}}]}],
#        'summary': '1 like'},
#       'logView': True,
#       'agreeCount': 1,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '27523953',
#        'firstName': 'Louise',
#        'lastName': 'Cheng',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/PHOEZ2EQ1DAEE1CV.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/bDBEvP',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 7,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 7,
#     'items': [{'id': '4fa5acbde4b0bbcd4a26d1d5',
#       'name': "Eddie's Eateries",
#       'description': 'Favourite places to eat',
#       'type': 'others',
#       'user': {'id': '18008936',
#        'firstName': 'Eddie',
#        'lastName': 'Chung',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/F3YIA0UIZ4TIPJHT.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/18008936/list/eddies-eateries',
#       'canonicalUrl': 'https://foursquare.com/user/18008936/list/eddies-eateries',
#       'createdAt': 1336257725,
#       'updatedAt': 1358720211,
#       'followers': {'count': 5},
#       'listItems': {'count': 18,
#        'items': [{'id': 'v4b8bffc6f964a52076b732e3',
#          'createdAt': 1336257998}]}},
#      {'id': '50193b97e4b00312afcab42f',
#       'name': 'Uptown',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '11704972',
#        'firstName': 'Teresa',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/FLP4BI13FZNXXM0N.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/11704972/list/uptown',
#       'canonicalUrl': 'https://foursquare.com/user/11704972/list/uptown',
#       'createdAt': 1343830935,
#       'updatedAt': 1356358254,
#       'photo': {'id': '500349c1e4b0004dbef00806',
#        'createdAt': 1342392769,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/v83pKqyeT6bhOPGV_q3Qslj45NCdIyCpdJuO5vqPqC8.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '12633694',
#         'firstName': 'Lea',
#         'lastName': 'Lansimaki',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/24OQDQ2JONFYX0IQ.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 8},
#       'listItems': {'count': 44,
#        'items': [{'id': 'v4b8bffc6f964a52076b732e3',
#          'createdAt': 1352746895}]}},
#      {'id': '4f385e2fe4b0cc4ce480d9be',
#       'name': 'Yonge & Shepp List',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '98343',
#        'firstName': 'Mark',
#        'lastName': 'S',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/98343-PQ2LLVXBHWLFL4JQ'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/mrseiks/list/yonge--shepp-list',
#       'canonicalUrl': 'https://foursquare.com/mrseiks/list/yonge--shepp-list',
#       'createdAt': 1329094191,
#       'updatedAt': 1404504880,
#       'followers': {'count': 3},
#       'listItems': {'count': 9,
#        'items': [{'id': 'v4b8bffc6f964a52076b732e3',
#          'createdAt': 1329094820}]}},
#      {'id': '504e2383e4b084386c074faa',
#       'name': 'Japanese',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '30512344',
#        'firstName': 'Nelson',
#        'lastName': 'DaSilva',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/30512344-GB3K2FROSDWTZWPJ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/30512344/list/japanese',
#       'canonicalUrl': 'https://foursquare.com/user/30512344/list/japanese',
#       'createdAt': 1347298179,
#       'updatedAt': 1394290555,
#       'followers': {'count': 1},
#       'listItems': {'count': 60,
#        'items': [{'id': 'v4b8bffc6f964a52076b732e3',
#          'createdAt': 1352714702}]}}]}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '6:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat', 'open': [{'renderedTime': 'Noon–1:00 AM'}], 'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '1:00 PM–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dinner, Lunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}]}]},
#  'bestPhoto': {'id': '50bc3284e4b0b98445db86e7',
#   'createdAt': 1354510980,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/16995036_1XBrQIjDtaIwuhIypjyS1GsFhPBEsH7YHvCyxd7MGzU.jpg',
#   'width': 540,
#   'height': 540,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '50bc3284e4b0b98445db86e7',
#    'value': -13623264},
#   'highlightTextColor': {'photoId': '50bc3284e4b0b98445db86e7', 'value': -1},
#   'algoVersion': 3}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.7

# %%
venue_id = '4ad89e97f964a520f01221e3' # ID 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.3

# %%
venue_id = '53e7f27c498e6a14dc56f611' # ID
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4f777209e4b0df5436c04da7' # ID
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.2

# %%
venue_id = '4b671ac9f964a520d73a2be3' # ID
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.5

# %% [markdown]
# ### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 14

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id="item5"></a>
